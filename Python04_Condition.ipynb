# %%
number = 15
if number > 0:
  print("The number is positive")
  
  score = 75
if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")

username = "icsear0404@gmail.com"
if len(username) > 0:
    print(f"Welcome, {username}!")
else:
    print("Error: Username cannot be empty")

a = 2
b = 330
print("A") if (a > b) else print("B")

a = 21
b = 20
bigger = a if a > b else b
print("Bigger is", bigger)

a = 332
b = 333
print("a가 b보다 크다") if a > b else print("a와 b는 같다") if a == b else print("b가 a보다 크다")

x = 15
y = 20
max_value = x if x > y else y
print("Maximum value:", max_value)

username = ""
display_name = username if username else "Guest"
print("Welcome,", display_name)

age = 25
is_student = False
has_discount_code = True
if (age < 18 or age > 65) and not is_student or has_discount_code:
    print("Discount applies!")

temperature = 25
is_raining = False
is_weekend = True
if (temperature > 20 and not is_raining) or is_weekend:
    print("Great day for outdoor activities!")

username = "Tobias"
password = "secret123"
is_verified = True
if username and password and is_verified:
    print("Login successful")
else:
    print("Login failed")

x = 21
if x > 10:
    print("Above ten,")
    if x > 20:
        print("and also above 20!")
    else:
        print("but not above 20.")
else:
    print("Not above 10.")

score = 55
attendance = 90
submitted = False
if score >= 60:
    if attendance >= 80:
        if submitted:
            print("Pass with good standing")
        else:
            print("Pass but missing assignment")
    else:
        print("Pass but low attendance")
else:
    print("Fail")

temperature = 19
is_sunny = False
print("Perfect!") if (temperature > 20 and is_sunny) else (print("Good~") if (temperature > 20 or is_sunny) else print("Bad"))

day = 4
match day:
  case 1:
        print("Monday")
  case 2:
        print("Tuesday")
  case 3:
        print("Wednesday")
  case 4:
        print("Thursday")
  case 5:
        print("Friday")
  case 6:
        print("Saturday")
  case 7:
        print("Sunday")

fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)
    if x == "banana":
        break

fruits = ["apple", "banana", "cherry"]
for x in fruits:
    if x == "banana":
        break
    print(x)
# Out:
# The number is positive
# Grade: C
# Welcome, icsear0404@gmail.com!
# B
# Bigger is 21
# b가 a보다 크다
# Maximum value: 20
# Welcome, Guest
# Discount applies!
# Great day for outdoor activities!
# Login successful
# Above ten,
# and also above 20!
# Fail
# Bad
# Thursday
# apple
# banana
# apple
